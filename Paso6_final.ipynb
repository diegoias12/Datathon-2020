# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
from sklearn.metrics import confusion_matrix

# %%
test = pd.read_csv('final_results.csv')
test.head()
# Out:
#               source                 target
# 0      Curt H. Davis          A. A. Soliman
# 1    Colin Studholme  A. Ardeshir Goshtasby
# 2  Lawrence H. Staib  A. Ardeshir Goshtasby
# 3        Ivan Marsic  A. Ardeshir Goshtasby
# 4       Ertem Tuncel  A. Ardeshir Goshtasby

# %%
df = pd.read_csv('edges.csv')
print(df.shape)
df.head(10)
# Out:
# (284654, 2)
#          source                         target
# 0  Aly A. Farag             Elsayed E. Hemayed
# 1  Aly A. Farag                Moumen T. Ahmed
# 2  Aly A. Farag                Sameh M. Yamany
# 3  Aly A. Farag  Mostafa Gadal-Haqq M. Mostafa
# 4  Aly A. Farag                   David Tasman
# 5  Aly A. Farag                Allan G. Farman
# 6  Aly A. Farag               Mohamed N. Ahmed
# 7  Aly A. Farag                       S. Ahmed
# 8  Aly A. Farag                     S. Roberts
# 9  Aly A. Farag                 Edward J. Delp

# %%
G = nx.Graph()

for _, row in df.iterrows():
    G.add_edge(row['source'], row['target'])

# %%
tuples = [tuple(x) for x in test.to_numpy()]
tuples[:5]
# Out:
# [('Curt H. Davis', 'A. A. Soliman'),
#  ('Colin Studholme', 'A. Ardeshir Goshtasby'),
#  ('Lawrence H. Staib', 'A. Ardeshir Goshtasby'),
#  ('Ivan Marsic', 'A. Ardeshir Goshtasby'),
#  ('Ertem Tuncel', 'A. Ardeshir Goshtasby')]

# %%
def Link_predict(s, t, j_c):
    if s in G and t in G:
        
        if not nx.has_path(G,s,t):
            return False
        
        if nx.shortest_path_length(G,s,t) < 4:
            return True
        
        aux = len(list(nx.common_neighbors(G,s,t)))/400
        pred = nx.jaccard_coefficient(G, [(s, t)])
        for _, _, p in pred:
            return (p + aux > j_c)
        
    return False

# %%
predictions = []
for elem in tuples:
    # predictions.append('P' if np.random.rand() > 0.5 else 'N')
    if Link_predict(elem[0], elem[1], 7/300):
        predictions.append('P')
    else:
        predictions.append('N')

# %% [markdown]
# tn, fp, fn, tp = confusion_matrix(y, predictions).ravel()
# print(tn, fp, fn, tp)
# precision = tp/(tp+fp)
# recall = tp/(tp+fn)
#
# print("precision", precision)
# print("recall", recall)
# print("f-value", 2*precision*recall/(precision+recall))

# %%
respuesta = test.copy()
respuesta['prediction'] = predictions
respuesta.head()
# Out:
#               source                 target prediction
# 0      Curt H. Davis          A. A. Soliman          N
# 1    Colin Studholme  A. Ardeshir Goshtasby          N
# 2  Lawrence H. Staib  A. Ardeshir Goshtasby          N
# 3        Ivan Marsic  A. Ardeshir Goshtasby          N
# 4       Ertem Tuncel  A. Ardeshir Goshtasby          N

# %%
respuesta
# Out:
#                            source                 target prediction
# 0                   Curt H. Davis          A. A. Soliman          N
# 1                 Colin Studholme  A. Ardeshir Goshtasby          N
# 2               Lawrence H. Staib  A. Ardeshir Goshtasby          N
# 3                     Ivan Marsic  A. Ardeshir Goshtasby          N
# 4                    Ertem Tuncel  A. Ardeshir Goshtasby          N
# 5                    Lee M. Garth          A. C. Cem Say          N
# 6                       Ion Petre          A. C. Cem Say          N
# 7              Gagan L. Choudhury          A. C. Cem Say          N
# 8                     Donia Scott          A. C. Cem Say          N
# 9                 Alessio Carullo          A. C. Cem Say          N
# 10                  Wei Wang 0010        A. Chockalingam          N
# 11           Jesús Navarro-Moreno        A. Chockalingam          N
# 12                    Eldon Y. Li        A. Chockalingam          N
# 13                  Kaushal Chari        A. Chockalingam          N
# 14                  Paul L. Rosin      A. David Marshall          N
# 15                      Zhili Sun      A. David Marshall          N
# 16                  Mahbub Hassan     A. Donald Keedwell          N
# 17                    Peter Mihók     A. Donald Keedwell          N
# 18                Klaus Obermayer     A. Donald Keedwell          N
# 19             Thomas Stockhammer     A. Donald Keedwell          N
# 20                  Jia-Guang Sun     A. Donald Keedwell          N
# 21              Robert Kozma 0001     A. F. El-Bassiouny          N
# 22            Nageswara S. V. Rao     A. F. El-Bassiouny          N
# 23     Teresa Serrano-Gotarredona        A. Fazel Famili          N
# 24             Dennis F. Galletta        A. Graham Peace          P
# 25              James Y. L. Thong        A. Graham Peace          N
# 26                  M. P. Bekakos        A. Graham Peace          N
# 27               Paul W. H. Chung        A. Graham Peace          N
# 28                  H. Jeff Smith        A. Graham Peace          P
# 29              James R. McDonald        A. Graham Peace          N
# ...                           ...                    ...        ...
# 51870        Chanathip Namprempre        Éric Laugerotte          N
# 51871              Kwanghoon Sohn        Éric Laugerotte          N
# 51872               Guisheng Liao          Étienne Mémin          N
# 51873                   Jie Liang          Étienne Mémin          N
# 51874                 Zhuojun Liu          Étienne Mémin          N
# 51875              Andrea Mantler          Étienne Mémin          N
# 51876                   Phone Lin          Étienne Mémin          N
# 51877             Neil J. Gunther          Étienne Mémin          N
# 51878               Yongmin Zhang             Éva Tardos          N
# 51879             Nobuyuki Matsui          Óscar Ciaurri          N
# 51880          Douglas S. Bridges          Óscar Ciaurri          N
# 51881            Shyong Jian Shyu          Óscar Reinoso          N
# 51882               Horst Lichter          Óscar Reinoso          N
# 51883        Bertrand M. Hochwald          Óscar Reinoso          N
# 51884                 Russ Miller          Óscar Reinoso          N
# 51885                Chris Kimble         Ömer Egecioglu          N
# 51886                  C. K. Wong         Ömer Egecioglu          P
# 51887              Felisa Verdejo         Ömer Egecioglu          N
# 51888                H. Narayanan         Ömer Egecioglu          N
# 51889            José Félix Costa         Ömer Egecioglu          N
# 51890                Wen-Lian Hsu         Ömer Egecioglu          N
# 51891         Athanasios Migdalas            Ömer Morgül          N
# 51892               Ugur Güdükbay           Özgür Ulusoy          P
# 51893                Patrick Solé           Özgür Ulusoy          N
# 51894          Robert W. Williams           Özgür Ulusoy          N
# 51895                 Dae-Ki Hong     Ümit V. Çatalyürek          N
# 51896          R. Michael Buehrer     Ümit V. Çatalyürek          N
# 51897      Kameswara Rao Namuduri     Ümit V. Çatalyürek          N
# 51898             Constantin Popa     Ümit V. Çatalyürek          N
# 51899       Marcel J. T. Reinders     Ümit V. Çatalyürek          N
#
# [51900 rows x 3 columns]

# %%
respuesta.to_csv('final_results_14.csv', index=False)
